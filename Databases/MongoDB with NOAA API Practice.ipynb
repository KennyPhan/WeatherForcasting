# %%
# pip install pymongo

# %%
import pymongo
from pymongo import MongoClient

# %%
client = MongoClient("mongodb+srv://kennyphan136:Password@cluster0.p10u5c6.mongodb.net/")

# %%
client.list_database_names()

# %%
import requests
import pandas as pd
start_date, end_date = '2020-01-01', '2020-01-31'
start_goal = pd.date_range(start=start_date, end=end_date, freq='MS').strftime('%Y-%m-%d')
end_goal = pd.date_range(start=start_date, end=end_date, freq='M') .strftime('%Y-%m-%d')

token = "Password"
url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data"
data  = []
for i in range(0,start_goal.size):
    start = start_goal[i]
    end = end_goal[i]
    params = {
        "datasetid": "GHCND",
        "stationid": "GHCND:USW00003947",
        "units": "standard",
        "startdate": start,
        "enddate": end,
        "limit": 1_000}
    response = requests.get(url, params=params, headers={"Token": token}).json()
    data.append(response)

# %%
kc_w=data[0]['results']

# %%
#w=data[0]['results']
#for i in range(0,len (w)):
 #del w[i]['attributes']
#w

# %%
db = client['NOAA_Weather']
collection = db["KC"]
collection.insert_many(kc_w)

# %%
import requests
import pandas as pd
start_date, end_date = '2020-01-01', '2020-01-31'
start_goal = pd.date_range(start=start_date, end=end_date, freq='MS').strftime('%Y-%m-%d')
end_goal = pd.date_range(start=start_date, end=end_date, freq='M') .strftime('%Y-%m-%d')

token = "Password"
url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data"
data  = []
for i in range(0,start_goal.size):
    start = start_goal[i]
    end = end_goal[i]
    params = {
        "datasetid": "GHCND",
        "stationid": "GHCND:USW00023174",
        "units": "standard",
        "startdate": start,
        "enddate": end,
        "limit": 1_000}
    response = requests.get(url, params=params, headers={"Token": token}).json()
    data.append(response)

# %%
la_w=data[0]['results']

# %%
db = client['NOAA_Weather']
collection = db["LA"]
collection.insert_many(la_w)

# %%
import requests
import pandas as pd
start_date, end_date = '2020-01-01', '2020-01-31'
start_goal = pd.date_range(start=start_date, end=end_date, freq='MS').strftime('%Y-%m-%d')
end_goal = pd.date_range(start=start_date, end=end_date, freq='M') .strftime('%Y-%m-%d')

token = "Password"
url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data"
data  = []
for i in range(0,start_goal.size):
    start = start_goal[i]
    end = end_goal[i]
    params = {
        "datasetid": "GHCND",
        "stationid": "GHCND:USW00094789",
        "units": "standard",
        "startdate": start,
        "enddate": end,
        "limit": 1_000}
    response = requests.get(url, params=params, headers={"Token": token}).json()
    data.append(response)

# %%
ny_w=data[0]['results']
db = client['NOAA_Weather']
collection = db["NY"]
collection.insert_many(ny_w)

# %%
db = client['NOAA_Weather']
collection = db["NY"]

# %%
snow=collection.find({"datatype":"SNOW"})
print(snow)
# Out:
# <pymongo.cursor.Cursor object at 0x10f29ad10>

# %%
test = list(snow)
test
# Out:
# [{'_id': ObjectId('650c6b48aee76f52aebb12a5'),
#   'date': '2020-01-02T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb12b7'),
#   'date': '2020-01-03T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb12ca'),
#   'date': '2020-01-04T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb12de'),
#   'date': '2020-01-05T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb12f0'),
#   'date': '2020-01-06T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.3},
#  {'_id': ObjectId('650c6b48aee76f52aebb1303'),
#   'date': '2020-01-07T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb1315'),
#   'date': '2020-01-08T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb1327'),
#   'date': '2020-01-09T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb1339'),
#   'date': '2020-01-10T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb134b'),
#   'date': '2020-01-11T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb135e'),
#   'date': '2020-01-12T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb1371'),
#   'date': '2020-01-13T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb1384'),
#   'date': '2020-01-14T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb1397'),
#   'date': '2020-01-15T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb13aa'),
#   'date': '2020-01-16T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb13bd'),
#   'date': '2020-01-17T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb13cf'),
#   'date': '2020-01-18T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 1.6},
#  {'_id': ObjectId('650c6b48aee76f52aebb13e2'),
#   'date': '2020-01-19T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb13f4'),
#   'date': '2020-01-20T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb1406'),
#   'date': '2020-01-21T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb1418'),
#   'date': '2020-01-22T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb142a'),
#   'date': '2020-01-23T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb143c'),
#   'date': '2020-01-24T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb144f'),
#   'date': '2020-01-25T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb1462'),
#   'date': '2020-01-26T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb1474'),
#   'date': '2020-01-27T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb1486'),
#   'date': '2020-01-28T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb1498'),
#   'date': '2020-01-29T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb14aa'),
#   'date': '2020-01-30T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0},
#  {'_id': ObjectId('650c6b48aee76f52aebb14bc'),
#   'date': '2020-01-31T00:00:00',
#   'datatype': 'SNOW',
#   'station': 'GHCND:USW00094789',
#   'attributes': ',,W,',
#   'value': 0.0}]

# %%
df = pd.DataFrame(test)

# %%
df
# Out:
#                          _id                 date datatype            station  \
# 0   650c6b48aee76f52aebb12a5  2020-01-02T00:00:00     SNOW  GHCND:USW00094789
# 1   650c6b48aee76f52aebb12b7  2020-01-03T00:00:00     SNOW  GHCND:USW00094789
# 2   650c6b48aee76f52aebb12ca  2020-01-04T00:00:00     SNOW  GHCND:USW00094789
# 3   650c6b48aee76f52aebb12de  2020-01-05T00:00:00     SNOW  GHCND:USW00094789
# 4   650c6b48aee76f52aebb12f0  2020-01-06T00:00:00     SNOW  GHCND:USW00094789
# 5   650c6b48aee76f52aebb1303  2020-01-07T00:00:00     SNOW  GHCND:USW00094789
# 6   650c6b48aee76f52aebb1315  2020-01-08T00:00:00     SNOW  GHCND:USW00094789
# 7   650c6b48aee76f52aebb1327  2020-01-09T00:00:00     SNOW  GHCND:USW00094789
# 8   650c6b48aee76f52aebb1339  2020-01-10T00:00:00     SNOW  GHCND:USW00094789
# 9   650c6b48aee76f52aebb134b  2020-01-11T00:00:00     SNOW  GHCND:USW00094789
# 10  650c6b48aee76f52aebb135e  2020-01-12T00:00:00     SNOW  GHCND:USW00094789
# 11  650c6b48aee76f52aebb1371  2020-01-13T00:00:00     SNOW  GHCND:USW00094789
# 12  650c6b48aee76f52aebb1384  2020-01-14T00:00:00     SNOW  GHCND:USW00094789
# 13  650c6b48aee76f52aebb1397  2020-01-15T00:00:00     SNOW  GHCND:USW00094789
# 14  650c6b48aee76f52aebb13aa  2020-01-16T00:00:00     SNOW  GHCND:USW00094789
# 15  650c6b48aee76f52aebb13bd  2020-01-17T00:00:00     SNOW  GHCND:USW00094789
# 16  650c6b48aee76f52aebb13cf  2020-01-18T00:00:00     SNOW  GHCND:USW00094789
# 17  650c6b48aee76f52aebb13e2  2020-01-19T00:00:00     SNOW  GHCND:USW00094789
# 18  650c6b48aee76f52aebb13f4  2020-01-20T00:00:00     SNOW  GHCND:USW00094789
# 19  650c6b48aee76f52aebb1406  2020-01-21T00:00:00     SNOW  GHCND:USW00094789
# 20  650c6b48aee76f52aebb1418  2020-01-22T00:00:00     SNOW  GHCND:USW00094789
# 21  650c6b48aee76f52aebb142a  2020-01-23T00:00:00     SNOW  GHCND:USW00094789
# 22  650c6b48aee76f52aebb143c  2020-01-24T00:00:00     SNOW  GHCND:USW00094789
# 23  650c6b48aee76f52aebb144f  2020-01-25T00:00:00     SNOW  GHCND:USW00094789
# 24  650c6b48aee76f52aebb1462  2020-01-26T00:00:00     SNOW  GHCND:USW00094789
# 25  650c6b48aee76f52aebb1474  2020-01-27T00:00:00     SNOW  GHCND:USW00094789
# 26  650c6b48aee76f52aebb1486  2020-01-28T00:00:00     SNOW  GHCND:USW00094789
# 27  650c6b48aee76f52aebb1498  2020-01-29T00:00:00     SNOW  GHCND:USW00094789
# 28  650c6b48aee76f52aebb14aa  2020-01-30T00:00:00     SNOW  GHCND:USW00094789
# 29  650c6b48aee76f52aebb14bc  2020-01-31T00:00:00     SNOW  GHCND:USW00094789
#
#    attributes  value
# 0        ,,W,    0.0
# 1        ,,W,    0.0
# 2        ,,W,    0.0
# 3        ,,W,    0.0
# 4        ,,W,    0.3
# 5        ,,W,    0.0
# 6        ,,W,    0.0
# 7        ,,W,    0.0
# 8        ,,W,    0.0
# 9        ,,W,    0.0
# 10       ,,W,    0.0
# 11       ,,W,    0.0
# 12       ,,W,    0.0
# 13       ,,W,    0.0
# 14       ,,W,    0.0
# 15       ,,W,    0.0
# 16       ,,W,    1.6
# 17       ,,W,    0.0
# 18       ,,W,    0.0
# 19       ,,W,    0.0
# 20       ,,W,    0.0
# 21       ,,W,    0.0
# 22       ,,W,    0.0
# 23       ,,W,    0.0
# 24       ,,W,    0.0
# 25       ,,W,    0.0
# 26       ,,W,    0.0
# 27       ,,W,    0.0
# 28       ,,W,    0.0
# 29       ,,W,    0.0

# %%
client.close()
